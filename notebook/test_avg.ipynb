# %%
import pandas as pd

# %%
suffix = 'si'

# %%
df = pd.read_csv(f"oil_{suffix}.csv")
df = df.drop(['Unnamed: 0'],axis=1)
ax = df.plot(figsize=(12,8),title='Test')
ax.set_xlabel("Epochs")
ax.set_ylabel("Accuracy")
ax.xaxis.grid(True)
ax.yaxis.grid(True)
ax.set_ylim(30,100)
# Out:
# (30.0, 100.0)

# %%
df
# Out:
#        Domain 0  Domain 1   Domain 2   Domain 3   Domain 4
# 0     55.314961       NaN        NaN        NaN        NaN
# 1     53.543307       NaN        NaN        NaN        NaN
# 2     51.968504       NaN        NaN        NaN        NaN
# 3     52.952756       NaN        NaN        NaN        NaN
# 4     52.559055       NaN        NaN        NaN        NaN
# ...         ...       ...        ...        ...        ...
# 2495  43.700787  52.09713  79.004329  68.934911  65.988372
# 2496  43.503937  52.09713  78.787879  68.934911  65.988372
# 2497  43.700787  52.09713  79.004329  68.934911  65.988372
# 2498  43.503937  52.09713  79.004329  68.934911  65.988372
# 2499  43.503937  52.09713  79.004329  69.526627  65.988372
#
# [2500 rows x 5 columns]

# %%
df['Mean'] = df.mean(axis=1)

# %%
df
# Out:
#        Domain 0  Domain 1   Domain 2   Domain 3   Domain 4       Mean
# 0     55.314961       NaN        NaN        NaN        NaN  55.314961
# 1     53.543307       NaN        NaN        NaN        NaN  53.543307
# 2     51.968504       NaN        NaN        NaN        NaN  51.968504
# 3     52.952756       NaN        NaN        NaN        NaN  52.952756
# 4     52.559055       NaN        NaN        NaN        NaN  52.559055
# ...         ...       ...        ...        ...        ...        ...
# 2495  43.700787  52.09713  79.004329  68.934911  65.988372  61.945106
# 2496  43.503937  52.09713  78.787879  68.934911  65.988372  61.862446
# 2497  43.700787  52.09713  79.004329  68.934911  65.988372  61.945106
# 2498  43.503937  52.09713  79.004329  68.934911  65.988372  61.905736
# 2499  43.503937  52.09713  79.004329  69.526627  65.988372  62.024079
#
# [2500 rows x 6 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.to_csv(f'csv/{suffix}.csv')
